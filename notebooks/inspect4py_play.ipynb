# %%
# !inspect4py --version
# Out:
# inspect4py, version 0.0.8

# %%
repo = "SoftwareUnderstanding/inspect4py"
# %cd ../repos/
# !mkdir -p {repo} && git clone {f"https://github.com/{repo}.git"} {repo}
# !inspect4py -i {repo} -o ../outputs/{repo} \
    -r -html -cl -cf -dt -si -ast -sc -ld -rm -md -df
# Out:
# /home/hz65/Documents/PythonProjects/RepoSnipyLLM/repos
# Cloning into 'SoftwareUnderstanding/inspect4py'...
# remote: Enumerating objects: 3221, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 3221 (delta 6), reused 8 (delta 4), pack-reused 3197 (from 1)
# Receiving objects: 100% (3221/3221), 15.77 MiB | 34.29 MiB/s, done.
# Resolving deltas: 100% (1569/1569), done.
# Problem loading language file __init__() takes exactly 1 argument (2 given)
# Creating cf /home/hz65/Documents/PythonProjects/RepoSnipyLLM/outputs/SoftwareUnderstanding/inspect4py/inspect4py/control_flow
# Creating jsDir:../outputs/SoftwareUnderstanding/inspect4py/inspect4py/json_files
# Error when processing setup.py:  (<class 'UnboundLocalError'>, UnboundLocalError("local variable 'parser' referenced before assignment"), <traceback object at 0x7b1d19fb0300>)
# ...
